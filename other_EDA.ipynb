# %% [markdown]
# # Greg

# %% [markdown]
# # James

# %% [markdown]
# # Han

# %% [markdown]
# # Rachel

# %% [markdown]
# # Himasri

# %% [markdown]
# #### Analysis
# 1. ROI per genre
# 2. Popularity per genre
# 3. Avg worldwide gross per genre
# 4. Buget -> worldwide gross
# 5. Best runtime for movie
# 6. Best month to release the mvoie
#
# #### Variables to explore
# 1. Revenue = worldwide gross
# 2. Profit = Revenue - Budget

# %%
import pandas as pd

# %%
tmdb_df = pd.read_csv("zippedData/tmdb.movies.csv.gz", index_col = 0)
tmdb_df.head()
# Out:
#              genre_ids     id original_language  \
# 0      [12, 14, 10751]  12444                en
# 1  [14, 12, 16, 10751]  10191                en
# 2        [12, 28, 878]  10138                en
# 3      [16, 35, 10751]    862                en
# 4        [28, 878, 12]  27205                en
#
#                                  original_title  popularity release_date  \
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                      How to Train Your Dragon      28.734   2010-03-26
# 2                                    Iron Man 2      28.515   2010-05-07
# 3                                     Toy Story      28.005   1995-11-22
# 4                                     Inception      27.920   2010-07-16
#
#                                           title  vote_average  vote_count
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 1                      How to Train Your Dragon           7.7        7610
# 2                                    Iron Man 2           6.8       12368
# 3                                     Toy Story           7.9       10174
# 4                                     Inception           8.3       22186

# %%
tn_df = pd.read_csv("zippedData/tn.movie_budgets.csv.gz", index_col = 0)
tn_df
# Out:
#     release_date                                        movie  \
# id
# 1   Dec 18, 2009                                       Avatar
# 2   May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 3    Jun 7, 2019                                 Dark Phoenix
# 4    May 1, 2015                      Avengers: Age of Ultron
# 5   Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ..           ...                                          ...
# 78  Dec 31, 2018                                       Red 11
# 79   Apr 2, 1999                                    Following
# 80  Jul 13, 2005                Return to the Land of Wonders
# 81  Sep 29, 2015                         A Plague So Pleasant
# 82   Aug 5, 2005                            My Date With Drew
#
#    production_budget domestic_gross worldwide_gross
# id
# 1       $425,000,000   $760,507,625  $2,776,345,279
# 2       $410,600,000   $241,063,875  $1,045,663,875
# 3       $350,000,000    $42,762,350    $149,762,350
# 4       $330,600,000   $459,005,868  $1,403,013,963
# 5       $317,000,000   $620,181,382  $1,316,721,747
# ..               ...            ...             ...
# 78            $7,000             $0              $0
# 79            $6,000        $48,482        $240,495
# 80            $5,000         $1,338          $1,338
# 81            $1,400             $0              $0
# 82            $1,100       $181,041        $181,041
#
# [5782 rows x 5 columns]

# %%
rtmovies_df = pd.read_csv("zippedData/rt.movie_info.tsv.gz", sep='\t')
rtmovies_df
# Out:
#         id                                           synopsis rating  \
# 0        1  This gritty, fast-paced, and innovative police...      R
# 1        3  New York City, not-too-distant-future: Eric Pa...      R
# 2        5  Illeana Douglas delivers a superb performance ...      R
# 3        6  Michael Douglas runs afoul of a treacherous su...      R
# 4        7                                                NaN     NR
# ...    ...                                                ...    ...
# 1555  1996  Forget terrorists or hijackers -- there's a ha...      R
# 1556  1997  The popular Saturday Night Live sketch was exp...     PG
# 1557  1998  Based on a novel by Richard Powell, when the l...      G
# 1558  1999  The Sandlot is a coming-of-age story about a g...     PG
# 1559  2000  Suspended from the force, Paris cop Hubert is ...      R
#
#                                                   genre            director  \
# 0                   Action and Adventure|Classics|Drama    William Friedkin
# 1                     Drama|Science Fiction and Fantasy    David Cronenberg
# 2                     Drama|Musical and Performing Arts      Allison Anders
# 3                            Drama|Mystery and Suspense      Barry Levinson
# 4                                         Drama|Romance      Rodney Bennett
# ...                                                 ...                 ...
# 1555   Action and Adventure|Horror|Mystery and Suspense                 NaN
# 1556                 Comedy|Science Fiction and Fantasy        Steve Barron
# 1557  Classics|Comedy|Drama|Musical and Performing Arts      Gordon Douglas
# 1558    Comedy|Drama|Kids and Family|Sports and Fitness  David Mickey Evans
# 1559  Action and Adventure|Art House and Internation...                 NaN
#
#                                                 writer  theater_date  \
# 0                                       Ernest Tidyman   Oct 9, 1971
# 1                         David Cronenberg|Don DeLillo  Aug 17, 2012
# 2                                       Allison Anders  Sep 13, 1996
# 3                      Paul Attanasio|Michael Crichton   Dec 9, 1994
# 4                                         Giles Cooper           NaN
# ...                                                ...           ...
# 1555                                               NaN  Aug 18, 2006
# 1556  Terry Turner|Tom Davis|Dan Aykroyd|Bonnie Turner  Jul 23, 1993
# 1557                                               NaN   Jan 1, 1962
# 1558                  David Mickey Evans|Robert Gunter   Apr 1, 1993
# 1559                                        Luc Besson  Sep 27, 2001
#
#           dvd_date currency  box_office      runtime             studio
# 0     Sep 25, 2001      NaN         NaN  104 minutes                NaN
# 1      Jan 1, 2013        $     600,000  108 minutes  Entertainment One
# 2     Apr 18, 2000      NaN         NaN  116 minutes                NaN
# 3     Aug 27, 1997      NaN         NaN  128 minutes                NaN
# 4              NaN      NaN         NaN  200 minutes                NaN
# ...            ...      ...         ...          ...                ...
# 1555   Jan 2, 2007        $  33,886,034  106 minutes    New Line Cinema
# 1556  Apr 17, 2001      NaN         NaN   88 minutes  Paramount Vantage
# 1557  May 11, 2004      NaN         NaN  111 minutes                NaN
# 1558  Jan 29, 2002      NaN         NaN  101 minutes                NaN
# 1559  Feb 11, 2003      NaN         NaN   94 minutes  Columbia Pictures
#
# [1560 rows x 12 columns]

# %%
rtreviews_df = pd.read_csv("zippedData/rt.reviews.tsv.gz", sep='\t', encoding= 'unicode_escape' )
rtreviews_df
# Out:
#          id                                             review rating   fresh  \
# 0         3  A distinctly gallows take on contemporary fina...    3/5   fresh
# 1         3  It's an allegory in search of a meaning that n...    NaN  rotten
# 2         3  ... life lived in a bubble in financial dealin...    NaN   fresh
# 3         3  Continuing along a line introduced in last yea...    NaN   fresh
# 4         3             ... a perverse twist on neorealism...     NaN   fresh
# ...     ...                                                ...    ...     ...
# 54427  2000  The real charm of this trifle is the deadpan c...    NaN   fresh
# 54428  2000                                                NaN    1/5  rotten
# 54429  2000                                                NaN    2/5  rotten
# 54430  2000                                                NaN  2.5/5  rotten
# 54431  2000                                                NaN    3/5   fresh
#
#                   critic  top_critic         publisher                date
# 0             PJ Nabarro           0   Patrick Nabarro   November 10, 2018
# 1         Annalee Newitz           0           io9.com        May 23, 2018
# 2           Sean Axmaker           0  Stream on Demand     January 4, 2018
# 3          Daniel Kasman           0              MUBI   November 16, 2017
# 4                    NaN           0      Cinema Scope    October 12, 2017
# ...                  ...         ...               ...                 ...
# 54427      Laura Sinagra           1     Village Voice  September 24, 2002
# 54428  Michael Szymanski           0        Zap2it.com  September 21, 2005
# 54429       Emanuel Levy           0   EmanuelLevy.Com       July 17, 2005
# 54430   Christopher Null           0    Filmcritic.com   September 7, 2003
# 54431    Nicolas Lacroix           0      Showbizz.net   November 12, 2002
#
# [54432 rows x 8 columns]

# %%
import sqlite3
import pandas as pd
import regex as re
from zipfile import ZipFile

# %%
#conn = sqlite3.connect('zippedData/im.db')

# %%
file_name = "./zippedData/im.db.zip"
# opening the zip file in READ mode
with ZipFile(file_name, 'r') as zip:
    # printing all the contents of the zip file
    #zip.printdir()
    zip.extractall()

# %%
conn = sqlite3.connect('./im.db')
#cur = conn.cursor()

# %%
# Table names
pd.read_sql('''
SELECT 
    name
FROM 
    sqlite_schema
WHERE 
    type ='table' AND 
    name NOT LIKE 'sqlite_%';
''',conn)
# Out:
#             name
# 0   movie_basics
# 1      directors
# 2      known_for
# 3     movie_akas
# 4  movie_ratings
# 5        persons
# 6     principals
# 7        writers

# %%
q = """ SELECT * FROM movie_basics """
movie_basics_df = pd.read_sql(q,conn)

# %%
movie_basics_df
# Out:
#          movie_id                                primary_title  \
# 0       tt0063540                                    Sunghursh
# 1       tt0066787              One Day Before the Rainy Season
# 2       tt0069049                   The Other Side of the Wind
# 3       tt0069204                              Sabse Bada Sukh
# 4       tt0100275                     The Wandering Soap Opera
# ...           ...                                          ...
# 146139  tt9916538                          Kuambil Lagi Hatiku
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                              Dankyavar Danka
# 146142  tt9916730                                       6 Gunn
# 146143  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 0                                         Sunghursh        2013
# 1                                   Ashad Ka Ek Din        2019
# 2                        The Other Side of the Wind        2018
# 3                                   Sabse Bada Sukh        2018
# 4                             La Telenovela Errante        2017
# ...                                             ...         ...
# 146139                          Kuambil Lagi Hatiku        2019
# 146140  Rodolpho Teóphilo - O Legado de um Pioneiro        2015
# 146141                              Dankyavar Danka        2013
# 146142                                       6 Gunn        2017
# 146143               Chico Albuquerque - Revelações        2013
#
#         runtime_minutes                genres
# 0                 175.0    Action,Crime,Drama
# 1                 114.0       Biography,Drama
# 2                 122.0                 Drama
# 3                   NaN          Comedy,Drama
# 4                  80.0  Comedy,Drama,Fantasy
# ...                 ...                   ...
# 146139            123.0                 Drama
# 146140              NaN           Documentary
# 146141              NaN                Comedy
# 146142            116.0                  None
# 146143              NaN           Documentary
#
# [146144 rows x 6 columns]

# %%
q = """ SELECT * FROM directors """
directors_df = pd.read_sql(q,conn)

# %%
directors_df
# Out:
#          movie_id   person_id
# 0       tt0285252   nm0899854
# 1       tt0462036   nm1940585
# 2       tt0835418   nm0151540
# 3       tt0835418   nm0151540
# 4       tt0878654   nm0089502
# ...           ...         ...
# 291169  tt8999974  nm10122357
# 291170  tt9001390   nm6711477
# 291171  tt9001494  nm10123242
# 291172  tt9001494  nm10123248
# 291173  tt9004986   nm4993825
#
# [291174 rows x 2 columns]

# %%
q = """ SELECT * FROM known_for """
known_for_df = pd.read_sql(q,conn)
known_for_df
# Out:
#          person_id   movie_id
# 0        nm0061671  tt0837562
# 1        nm0061671  tt2398241
# 2        nm0061671  tt0844471
# 3        nm0061671  tt0118553
# 4        nm0061865  tt0896534
# ...            ...        ...
# 1638255  nm9990690  tt9090932
# 1638256  nm9990690  tt8737130
# 1638257  nm9991320  tt8734436
# 1638258  nm9991320  tt9615610
# 1638259  nm9993380  tt8743182
#
# [1638260 rows x 2 columns]

# %%
q = """ SELECT * FROM persons """
persons_df = pd.read_sql(q,conn)
persons_df
# Out:
#         person_id         primary_name  birth_year  death_year  \
# 0       nm0061671    Mary Ellen Bauder         NaN         NaN
# 1       nm0061865         Joseph Bauer         NaN         NaN
# 2       nm0062070           Bruce Baum         NaN         NaN
# 3       nm0062195         Axel Baumann         NaN         NaN
# 4       nm0062798          Pete Baxter         NaN         NaN
# ...           ...                  ...         ...         ...
# 606643  nm9990381         Susan Grobes         NaN         NaN
# 606644  nm9990690          Joo Yeon So         NaN         NaN
# 606645  nm9991320       Madeline Smith         NaN         NaN
# 606646  nm9991786  Michelle Modigliani         NaN         NaN
# 606647  nm9993380       Pegasus Envoyé         NaN         NaN
#
#                                       primary_profession
# 0              miscellaneous,production_manager,producer
# 1             composer,music_department,sound_department
# 2                             miscellaneous,actor,writer
# 3       camera_department,cinematographer,art_department
# 4       production_designer,art_department,set_decorator
# ...                                                  ...
# 606643                                           actress
# 606644                                           actress
# 606645                                           actress
# 606646                                          producer
# 606647                             director,actor,writer
#
# [606648 rows x 5 columns]

# %%
q = """ SELECT * FROM principals """
principals_df = pd.read_sql(q,conn)
principals_df
# Out:
#           movie_id  ordering   person_id  category       job  \
# 0        tt0111414         1   nm0246005     actor      None
# 1        tt0111414         2   nm0398271  director      None
# 2        tt0111414         3   nm3739909  producer  producer
# 3        tt0323808        10   nm0059247    editor      None
# 4        tt0323808         1   nm3579312   actress      None
# ...            ...       ...         ...       ...       ...
# 1028181  tt9692684         1   nm0186469     actor      None
# 1028182  tt9692684         2   nm4929530      self      None
# 1028183  tt9692684         3  nm10441594  director      None
# 1028184  tt9692684         4   nm6009913    writer    writer
# 1028185  tt9692684         5  nm10441595  producer  producer
#
#                    characters
# 0                 ["The Man"]
# 1                        None
# 2                        None
# 3                        None
# 4            ["Beth Boothby"]
# ...                       ...
# 1028181  ["Ebenezer Scrooge"]
# 1028182   ["Herself","Regan"]
# 1028183                  None
# 1028184                  None
# 1028185                  None
#
# [1028186 rows x 6 columns]

# %%
q = """ SELECT * FROM writers """
writers_df = pd.read_sql(q,conn)
writers_df
# Out:
#          movie_id   person_id
# 0       tt0285252   nm0899854
# 1       tt0438973   nm0175726
# 2       tt0438973   nm1802864
# 3       tt0462036   nm1940585
# 4       tt0835418   nm0310087
# ...           ...         ...
# 255868  tt8999892  nm10122246
# 255869  tt8999974  nm10122357
# 255870  tt9001390   nm6711477
# 255871  tt9004986   nm4993825
# 255872  tt9010172   nm8352242
#
# [255873 rows x 2 columns]

# %%
q = """ SELECT * FROM movie_ratings """
movie_ratings_df = pd.read_sql(q,conn)

# %%
movie_ratings_df
# Out:
#          movie_id  averagerating  numvotes
# 0      tt10356526            8.3        31
# 1      tt10384606            8.9       559
# 2       tt1042974            6.4        20
# 3       tt1043726            4.2     50352
# 4       tt1060240            6.5        21
# ...           ...            ...       ...
# 73851   tt9805820            8.1        25
# 73852   tt9844256            7.5        24
# 73853   tt9851050            4.7        14
# 73854   tt9886934            7.0         5
# 73855   tt9894098            6.3       128
#
# [73856 rows x 3 columns]

# %%
q = """ SELECT * FROM movie_akas """
movie_akas_df = pd.read_sql(q,conn)

# %%
movie_akas_df.head()
# Out:
#     movie_id  ordering                                    title region  \
# 0  tt0369610        10                            Джурасик свят     BG
# 1  tt0369610        11                        Jurashikku warudo     JP
# 2  tt0369610        12  Jurassic World: O Mundo dos Dinossauros     BR
# 3  tt0369610        13                  O Mundo dos Dinossauros     BR
# 4  tt0369610        14                           Jurassic World     FR
#
#   language        types   attributes  is_original_title
# 0       bg         None         None                0.0
# 1     None  imdbDisplay         None                0.0
# 2     None  imdbDisplay         None                0.0
# 3     None         None  short title                0.0
# 4     None  imdbDisplay         None                0.0

# %%
# Join movie_basics and movie ratings tables
joined_df = movie_ratings_df.merge(movie_basics_df, how="inner", on="movie_id")

# %%
#Shape of the dataset
joined_df.shape
# Out:
# (73856, 8)

# %%
# Check for Duplicate values
joined_df.duplicated().sum()
# Out:
# 0

# %%
#Check for null values
joined_df.isnull().sum()
# Out:
# movie_id              0
# averagerating         0
# numvotes              0
# primary_title         0
# original_title        0
# start_year            0
# runtime_minutes    7620
# genres              804
# dtype: int64

# %% [markdown]
# ##### There are missing values in runtime_minutes and genres column

# %%
# Drop rows with null values 
joined_df.dropna(subset = ["runtime_minutes", "genres"], inplace=True)

# %%
joined_df.isnull().sum()
# Out:
# movie_id           0
# averagerating      0
# numvotes           0
# primary_title      0
# original_title     0
# start_year         0
# runtime_minutes    0
# genres             0
# dtype: int64

# %%
joined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 65720 entries, 0 to 73855
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   movie_id         65720 non-null  object
#  1   averagerating    65720 non-null  float64
#  2   numvotes         65720 non-null  int64
#  3   primary_title    65720 non-null  object
#  4   original_title   65720 non-null  object
#  5   start_year       65720 non-null  int64
#  6   runtime_minutes  65720 non-null  float64
#  7   genres           65720 non-null  object
# dtypes: float64(2), int64(2), object(4)
# memory usage: 4.5+ MB

# %%
movie_gross_df = pd.read_csv("zippedData/bom.movie_gross.csv.gz", index_col = 0)
movie_gross_df.head()
# Out:
#                                             studio  domestic_gross  \
# title
# Toy Story 3                                     BV     415000000.0
# Alice in Wonderland (2010)                      BV     334200000.0
# Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# Inception                                       WB     292600000.0
# Shrek Forever After                           P/DW     238700000.0
#
#                                             foreign_gross  year
# title
# Toy Story 3                                     652000000  2010
# Alice in Wonderland (2010)                      691300000  2010
# Harry Potter and the Deathly Hallows Part 1     664300000  2010
# Inception                                       535700000  2010
# Shrek Forever After                             513900000  2010

# %%
movie_gross_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3387 entries, Toy Story 3 to An Actor Prepares
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   studio          3382 non-null   object
#  1   domestic_gross  3359 non-null   float64
#  2   foreign_gross   2037 non-null   object
#  3   year            3387 non-null   int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 132.3+ KB

# %% [markdown]
# ##### Foriegn gross - Object data type.
# ##### There are unnecessary characters in Foriegn Gross Column

# %%
# Remove the unnecessary characters using a regular expression
movie_gross_df['foreign_gross'] = movie_gross_df['foreign_gross'].replace('[$,()]', '', regex = True)

#Convert object to Float data type
movie_gross_df['foreign_gross'] = movie_gross_df['foreign_gross'].astype(float)

# %%
movie_gross_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3387 entries, Toy Story 3 to An Actor Prepares
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   studio          3382 non-null   object
#  1   domestic_gross  3359 non-null   float64
#  2   foreign_gross   2037 non-null   float64
#  3   year            3387 non-null   int64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 132.3+ KB

# %%
#Check for missing values
movie_gross_df.isna().sum()
# Out:
# studio               5
# domestic_gross      28
# foreign_gross     1350
# year                 0
# dtype: int64

# %%
#Check for duplicate values
movie_gross_df.duplicated().sum()
# Out:
# 11

# %%
movie_gross_df.dropna(inplace=True)

# %%
movie_gross_df.isna().sum()
# Out:
# studio            0
# domestic_gross    0
# foreign_gross     0
# year              0
# dtype: int64

# %%
#tn_df["year"] = tn_df["release_date"].map(lambda x: int(x[-4:]))

# %%
tn_df.head()
# Out:
#     release_date                                        movie  \
# id
# 1   Dec 18, 2009                                       Avatar
# 2   May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 3    Jun 7, 2019                                 Dark Phoenix
# 4    May 1, 2015                      Avengers: Age of Ultron
# 5   Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#    production_budget domestic_gross worldwide_gross
# id
# 1       $425,000,000   $760,507,625  $2,776,345,279
# 2       $410,600,000   $241,063,875  $1,045,663,875
# 3       $350,000,000    $42,762,350    $149,762,350
# 4       $330,600,000   $459,005,868  $1,403,013,963
# 5       $317,000,000   $620,181,382  $1,316,721,747

# %%
#map(lambda x :''.join(filter(str.isalnum, x)).lower())

# %%
#tn_df["month"] = tn_df["release_date"].map(lambda x: x[:3])
#tn_df.head()

# %%
def make_int(string):
    return int(string.replace("$","").replace(",",""))

# %%
tn_df['production_budget'] = tn_df['production_budget'].apply(lambda x: make_int(x))
tn_df['domestic_gross'] = tn_df['domestic_gross'].apply(lambda x: make_int(x))
tn_df['worldwide_gross'] = tn_df['worldwide_gross'].apply(lambda x: make_int(x))

# %%
#Convert to datetime object using datetime function
tn_df["release_date"] = pd.to_datetime(tn_df["release_date"], format = '%b %d, %Y')

# %%
#Create a column called days 
tn_df['days'] = tn_df["release_date"].dt.day_name()

# %%
#Create a column called months 
tn_df['months'] = tn_df["release_date"].dt.month_name()

# %%
tn_df['year'] = tn_df["release_date"].dt.year

# %%
tn_df.head()
# Out:
#    release_date                                        movie  \
# id
# 1    2009-12-18                                       Avatar
# 2    2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 3    2019-06-07                                 Dark Phoenix
# 4    2015-05-01                      Avengers: Age of Ultron
# 5    2017-12-15            Star Wars Ep. VIII: The Last Jedi
#
#     production_budget  domestic_gross  worldwide_gross    days    months  year
# id
# 1           425000000       760507625       2776345279  Friday  December  2009
# 2           410600000       241063875       1045663875  Friday       May  2011
# 3           350000000        42762350        149762350  Friday      June  2019
# 4           330600000       459005868       1403013963  Friday       May  2015
# 5           317000000       620181382       1316721747  Friday  December  2017

# %%
tn_df['ROI'] = (tn_df['worldwide_gross'] - tn_df['production_budget']) / tn_df['production_budget']
tn_df.head()
# Out:
#    release_date                                        movie  \
# id
# 1    2009-12-18                                       Avatar
# 2    2011-05-20  Pirates of the Caribbean: On Stranger Tides
# 3    2019-06-07                                 Dark Phoenix
# 4    2015-05-01                      Avengers: Age of Ultron
# 5    2017-12-15            Star Wars Ep. VIII: The Last Jedi
#
#     production_budget  domestic_gross  worldwide_gross    days    months  \
# id
# 1           425000000       760507625       2776345279  Friday  December
# 2           410600000       241063875       1045663875  Friday       May
# 3           350000000        42762350        149762350  Friday      June
# 4           330600000       459005868       1403013963  Friday       May
# 5           317000000       620181382       1316721747  Friday  December
#
#     year       ROI
# id
# 1   2009  5.532577
# 2   2011  1.546673
# 3   2019 -0.572108
# 4   2015  3.243841
# 5   2017  3.153696

# %%
#Filtering the dataset with movies released from the year 2000
tn_df = tn_df[tn_df['year'] >= 2000]

# %%
tn_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4387 entries, 1 to 82
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   release_date       4387 non-null   datetime64[ns]
#  1   movie              4387 non-null   object
#  2   production_budget  4387 non-null   int64
#  3   domestic_gross     4387 non-null   int64
#  4   worldwide_gross    4387 non-null   int64
#  5   days               4387 non-null   object
#  6   months             4387 non-null   object
#  7   year               4387 non-null   int64
#  8   ROI                4387 non-null   float64
# dtypes: datetime64[ns](1), float64(1), int64(4), object(3)
# memory usage: 342.7+ KB

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline 

fig,ax = plt.subplots(figsize=(14,7))
sns.barplot(data = tn_df, x='months', y='ROI')
ax.set_ylabel('ROI', fontsize=13)
ax.set_xlabel('Months', fontsize=13)
ax.set_title('ROI of movies released in each month', fontsize=13)
# Out:
# Text(0.5, 1.0, 'ROI of movies released in each month')

# %% [markdown]
# ##### Need to sort the months in order for the x-axis

# %%
#Create a dictionary 
months_dict = { 'January': 1, 'February': 2, 'March': 3, 'April': 4, 'May': 5, 'June': 6, 'July': 7, 'August': 8, 'September': 9, 'October': 10, 'November': 11, 'December': 12}

#Map the dictionary to the 'month' column 
tn_df['months_numeric'] = tn_df['months'].apply(lambda x: months_dict.get(x))

#Sort the numeric months column in the ascending order
tn_df = tn_df.sort_values('months_numeric')
# Out:
# C:\Users\hmorareddy\AppData\Local\Temp\ipykernel_23632\368310665.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tn_df['months_numeric'] = tn_df['months'].apply(lambda x: months_dict.get(x))

# %%
tn_df
# Out:
#    release_date                                              movie  \
# id
# 87   2008-01-11  The Pirates Who Don't Do Anything: A VeggieTal...
# 92   2015-01-27                                        Born of War
# 88   2007-01-30                              Farce of the Penguins
# 91   2017-01-06                             Underworld: Blood Wars
# 94   2008-01-25                                        Untraceable
# ..          ...                                                ...
# 68   2006-12-31                   Les BronzÃ©s 3: amis pour la vie
# 65   2010-12-03                                  The Warrior's Way
# 58   2018-12-25                                    Holmes & Watson
# 26   2012-12-31                                         Foodfight!
# 1    2009-12-18                                             Avatar
#
#     production_budget  domestic_gross  worldwide_gross     days    months  \
# id
# 87           15000000        12981269         13248444   Friday   January
# 92            5000000               0                0  Tuesday   January
# 88            5000000               0                0  Tuesday   January
# 91           35000000        30353973         81209222   Friday   January
# 94           35000000        28687835         52649951   Friday   January
# ..                ...             ...              ...      ...       ...
# 68           42000000               0         83833602   Sunday  December
# 65           42000000         5666340          8514325   Friday  December
# 58           42000000        30568743         41926605  Tuesday  December
# 26           45000000               0            73706   Monday  December
# 1           425000000       760507625       2776345279   Friday  December
#
#     year       ROI  months_numeric
# id
# 87  2008 -0.116770               1
# 92  2015 -1.000000               1
# 88  2007 -1.000000               1
# 91  2017  1.320263               1
# 94  2008  0.504284               1
# ..   ...       ...             ...
# 68  2006  0.996038              12
# 65  2010 -0.797278              12
# 58  2018 -0.001747              12
# 26  2012 -0.998362              12
# 1   2009  5.532577              12
#
# [4387 rows x 10 columns]

# %%
tn_df['profit'] = (tn_df['worldwide_gross'] - tn_df['production_budget'])
tn_df.head()
# Out:
#    release_date                                              movie  \
# id
# 87   2008-01-11  The Pirates Who Don't Do Anything: A VeggieTal...
# 92   2015-01-27                                        Born of War
# 88   2007-01-30                              Farce of the Penguins
# 91   2017-01-06                             Underworld: Blood Wars
# 94   2008-01-25                                        Untraceable
#
#     production_budget  domestic_gross  worldwide_gross     days   months  \
# id
# 87           15000000        12981269         13248444   Friday  January
# 92            5000000               0                0  Tuesday  January
# 88            5000000               0                0  Tuesday  January
# 91           35000000        30353973         81209222   Friday  January
# 94           35000000        28687835         52649951   Friday  January
#
#     year       ROI  months_numeric    profit
# id
# 87  2008 -0.116770               1  -1751556
# 92  2015 -1.000000               1  -5000000
# 88  2007 -1.000000               1  -5000000
# 91  2017  1.320263               1  46209222
# 94  2008  0.504284               1  17649951

# %%
tn_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4387 entries, 87 to 1
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   release_date       4387 non-null   datetime64[ns]
#  1   movie              4387 non-null   object
#  2   production_budget  4387 non-null   int64
#  3   domestic_gross     4387 non-null   int64
#  4   worldwide_gross    4387 non-null   int64
#  5   days               4387 non-null   object
#  6   months             4387 non-null   object
#  7   year               4387 non-null   int64
#  8   ROI                4387 non-null   float64
#  9   months_numeric     4387 non-null   int64
#  10  profit             4387 non-null   int64
# dtypes: datetime64[ns](1), float64(1), int64(6), object(3)
# memory usage: 411.3+ KB

# %%
fig,ax = plt.subplots(figsize=(14,7))
sns.barplot(data = tn_df, x='months', y='profit')
ax.set_ylabel('Profit', fontsize=13)
ax.set_xlabel('Months', fontsize=13)
ax.set_title('Monthly profit of movies (2000-2020) ', fontsize=13)
# Out:
# Text(0.5, 1.0, 'Monthly profit of movies (2000-2020) ')

# %%
fig,ax = plt.subplots(figsize=(14,7))
sns.boxplot(data = tn_df, x='months', y='worldwide_gross',showfliers=0, whis=0 )
ax.set_ylabel(' Worldwide Gross', fontsize=13)
ax.set_xlabel('Months', fontsize=13)
ax.set_title('Monthly Worldwide Gross earnings of movies (2000-2020) ', fontsize=13)
# Out:
# Text(0.5, 1.0, 'Monthly Worldwide Gross earnings of movies (2000-2020) ')

# %%
#Create function for season

def season(s):
    return s.map(lambda x: "Winter" if x > 11 or x<3
                 else ("Spring" if x>=3 and x<6
                       else("Summer" if x>5 and x<9
                            else("Fall"))))

tn_df["season"] = season(tn_df["months_numeric"])

# %%
tn_df["season"].value_counts()
# Out:
# Fall      1187
# Winter    1133
# Spring    1045
# Summer    1022
# Name: season, dtype: int64

# %%
fig,ax = plt.subplots(figsize=(8,4))
sns.boxplot(data = tn_df, x='season', y='worldwide_gross',showfliers=0, whis=0 )
ax.set_ylabel(' Worldwide Gross', fontsize=13)
ax.set_xlabel('Seasons', fontsize=13)
ax.set_title('Seasonal Worldwide Gross earnings of movies (2000-2020) ', fontsize=13)
# Out:
# Text(0.5, 1.0, 'Seasonal Worldwide Gross earnings of movies (2000-2020) ')

# %%
#Analysis of Gross earnings of movies and season over the last 2 decades
season_gross = (tn_df.groupby(["year","season"])['worldwide_gross'].mean()).sort_values(ascending = False)
season_gross.head()
# Out:
# year  season
# 2018  Summer    2.126597e+08
# 2017  Spring    2.032295e+08
#       Summer    2.009847e+08
# 2018  Spring    1.951302e+08
# 2016  Summer    1.782752e+08
# Name: worldwide_gross, dtype: float64

# %%
#season_profit = (tn_df.groupby(["year","season"])['profit'].mean()).sort_values(ascending = False)

# %%
#plt.figure(figsize=(15,8))
#ax = sns.stripplot(x=tn_df.year , y=tn_df.profit, data=tn_df)
#ax.set_title("Profit vs Release Year", fontsize=17)
#ax.set_ylabel('Profit', fontsize=13)
#ax.set_xlabel('Release year', fontsize=13)

# %%
#Creates a new title column
tn_df["title"]= tn_df["movie"].map(lambda x :''.join(filter(str.isalnum, x)).lower())
tn_df.head()
# Out:
#    release_date                                              movie  \
# id
# 87   2008-01-11  The Pirates Who Don't Do Anything: A VeggieTal...
# 92   2015-01-27                                        Born of War
# 88   2007-01-30                              Farce of the Penguins
# 91   2017-01-06                             Underworld: Blood Wars
# 94   2008-01-25                                        Untraceable
#
#     production_budget  domestic_gross  worldwide_gross     days   months  \
# id
# 87           15000000        12981269         13248444   Friday  January
# 92            5000000               0                0  Tuesday  January
# 88            5000000               0                0  Tuesday  January
# 91           35000000        30353973         81209222   Friday  January
# 94           35000000        28687835         52649951   Friday  January
#
#     year       ROI  months_numeric    profit  season  \
# id
# 87  2008 -0.116770               1  -1751556  Winter
# 92  2015 -1.000000               1  -5000000  Winter
# 88  2007 -1.000000               1  -5000000  Winter
# 91  2017  1.320263               1  46209222  Winter
# 94  2008  0.504284               1  17649951  Winter
#
#                                            title
# id
# 87  thepirateswhodontdoanythingaveggietalesmovie
# 92                                     bornofwar
# 88                            farceofthepenguins
# 91                           underworldbloodwars
# 94                                   untraceable

# %%
#Create query 
q = """
SELECT * 
FROM movie_basics
"""
#create a DF from the IMBD sql table
imdb_movie_ratings = pd.read_sql(q, conn)
#remove na's from the original title due to low numbers
imdb_movie_ratings.dropna(subset=['original_title'], inplace = True)
imdb_movie_ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 146123 entries, 0 to 146143
# Data columns (total 6 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   movie_id         146123 non-null  object
#  1   primary_title    146123 non-null  object
#  2   original_title   146123 non-null  object
#  3   start_year       146123 non-null  int64
#  4   runtime_minutes  114401 non-null  float64
#  5   genres           140734 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 7.8+ MB

# %%
#create a column for movie names to merge with other DFs   tn_movie_budgets
imdb_movie_ratings['title'] = imdb_movie_ratings['original_title'].map(lambda x :''.join(filter(str.isalnum, x)).lower())

#sets the index on the title field for the merge
tn_df.set_index('title', inplace=True)
imdb_movie_ratings.set_index('title', inplace=True)
imdb_movie_ratings.head()
# Out:
#                         movie_id                    primary_title  \
# title
# sunghursh              tt0063540                        Sunghursh
# ashadkaekdin           tt0066787  One Day Before the Rainy Season
# theothersideofthewind  tt0069049       The Other Side of the Wind
# sabsebadasukh          tt0069204                  Sabse Bada Sukh
# latelenovelaerrante    tt0100275         The Wandering Soap Opera
#
#                                    original_title  start_year  \
# title
# sunghursh                               Sunghursh        2013
# ashadkaekdin                      Ashad Ka Ek Din        2019
# theothersideofthewind  The Other Side of the Wind        2018
# sabsebadasukh                     Sabse Bada Sukh        2018
# latelenovelaerrante         La Telenovela Errante        2017
#
#                        runtime_minutes                genres
# title
# sunghursh                        175.0    Action,Crime,Drama
# ashadkaekdin                     114.0       Biography,Drama
# theothersideofthewind            122.0                 Drama
# sabsebadasukh                      NaN          Comedy,Drama
# latelenovelaerrante               80.0  Comedy,Drama,Fantasy

# %%
#combine imdb and the numbers tables
#rating_and_budgets = tn_df.join(imdb_movie_ratings, how = 'inner')
#rating_and_budgets.reset_index(inplace=True)
#rating_and_budgets = rating_and_budgets.drop_duplicates(subset='title', keep="first")
#rating_and_budgets

#merge tn_movie_budgets and imdb_title_basics as df
rating_and_budgets = pd.merge(imdb_movie_ratings.reset_index(), tn_df,
             left_on=['primary_title', 'start_year'],
             right_on=['movie', 'year'])

#drop duplicate columns (primary_title, start_year)
rating_and_budgets = rating_and_budgets.drop(['primary_title','start_year'], axis = 1)

#reset index to tconst
rating_and_budgets =  rating_and_budgets.set_index('movie_id')

#check data
rating_and_budgets
# Out:
#                                 title                   original_title  \
# movie_id
# tt0249516                   foodfight                       Foodfight!
# tt0359950  thesecretlifeofwaltermitty  The Secret Life of Walter Mitty
# tt0365907     awalkamongthetombstones      A Walk Among the Tombstones
# tt0369610               jurassicworld                   Jurassic World
# tt0376136                 therumdiary                    The Rum Diary
# ...                               ...                              ...
# tt8364368                       crawl                            Crawl
# tt8408152                   detention                        Detention
# tt8632862               fahrenheit119                  Fahrenheit 11/9
# tt8852552                      icarus                           Icarus
# tt9024106                   unplanned                        Unplanned
#
#            runtime_minutes                   genres release_date  \
# movie_id
# tt0249516             91.0  Action,Animation,Comedy   2012-12-31
# tt0359950            114.0   Adventure,Comedy,Drama   2013-12-25
# tt0365907            114.0       Action,Crime,Drama   2014-09-19
# tt0369610            124.0  Action,Adventure,Sci-Fi   2015-06-12
# tt0376136            119.0             Comedy,Drama   2011-10-28
# ...                    ...                      ...          ...
# tt8364368              NaN   Action,Horror,Thriller   2019-07-12
# tt8408152              NaN                   Horror   2012-04-13
# tt8632862            128.0              Documentary   2018-09-21
# tt8852552             78.0                 Thriller   2010-02-09
# tt9024106            106.0          Biography,Drama   2019-03-29
#
#                                      movie  production_budget  domestic_gross  \
# movie_id
# tt0249516                       Foodfight!           45000000               0
# tt0359950  The Secret Life of Walter Mitty           91000000        58236838
# tt0365907      A Walk Among the Tombstones           28000000        26017685
# tt0369610                   Jurassic World          215000000       652270625
# tt0376136                    The Rum Diary           45000000        13109815
# ...                                    ...                ...             ...
# tt8364368                            Crawl           17000000               0
# tt8408152                        Detention           10000000               0
# tt8632862                  Fahrenheit 11/9            5000000         6352306
# tt8852552                           Icarus            6000000               0
# tt9024106                        Unplanned            6000000        18107621
#
#            worldwide_gross       days     months  year       ROI  \
# movie_id
# tt0249516            73706     Monday   December  2012 -0.998362
# tt0359950        187861183  Wednesday   December  2013  1.064409
# tt0365907         62108587     Friday  September  2014  1.218164
# tt0369610       1648854864     Friday       June  2015  6.669092
# tt0376136         21544732     Friday    October  2011 -0.521228
# ...                    ...        ...        ...   ...       ...
# tt8364368                0     Friday       July  2019 -1.000000
# tt8408152                0     Friday      April  2012 -1.000000
# tt8632862          6653715     Friday  September  2018  0.330743
# tt8852552                0    Tuesday   February  2010 -1.000000
# tt9024106         18107621     Friday      March  2019  2.017937
#
#            months_numeric      profit  season
# movie_id
# tt0249516              12   -44926294  Winter
# tt0359950              12    96861183  Winter
# tt0365907               9    34108587    Fall
# tt0369610               6  1433854864  Summer
# tt0376136              10   -23455268    Fall
# ...                   ...         ...     ...
# tt8364368               7   -17000000  Summer
# tt8408152               4   -10000000  Spring
# tt8632862               9     1653715    Fall
# tt8852552               2    -6000000  Winter
# tt9024106               3    12107621  Spring
#
# [1547 rows x 16 columns]

# %%
# Explode the genres
# Convert values into string and split them
rating_and_budgets['genres'] = rating_and_budgets['genres'].str.split(",")
# Convert values into list of strings
rating_and_budgets['genres'] = rating_and_budgets['genres'].tolist()
# Explode list into individual values
rating_and_budgets = rating_and_budgets.explode('genres')
rating_and_budgets.head()
# Out:
#                                 title                   original_title  \
# movie_id
# tt0249516                   foodfight                       Foodfight!
# tt0249516                   foodfight                       Foodfight!
# tt0249516                   foodfight                       Foodfight!
# tt0359950  thesecretlifeofwaltermitty  The Secret Life of Walter Mitty
# tt0359950  thesecretlifeofwaltermitty  The Secret Life of Walter Mitty
#
#            runtime_minutes     genres release_date  \
# movie_id
# tt0249516             91.0     Action   2012-12-31
# tt0249516             91.0  Animation   2012-12-31
# tt0249516             91.0     Comedy   2012-12-31
# tt0359950            114.0  Adventure   2013-12-25
# tt0359950            114.0     Comedy   2013-12-25
#
#                                      movie  production_budget  domestic_gross  \
# movie_id
# tt0249516                       Foodfight!           45000000               0
# tt0249516                       Foodfight!           45000000               0
# tt0249516                       Foodfight!           45000000               0
# tt0359950  The Secret Life of Walter Mitty           91000000        58236838
# tt0359950  The Secret Life of Walter Mitty           91000000        58236838
#
#            worldwide_gross       days    months  year       ROI  \
# movie_id
# tt0249516            73706     Monday  December  2012 -0.998362
# tt0249516            73706     Monday  December  2012 -0.998362
# tt0249516            73706     Monday  December  2012 -0.998362
# tt0359950        187861183  Wednesday  December  2013  1.064409
# tt0359950        187861183  Wednesday  December  2013  1.064409
#
#            months_numeric    profit  season
# movie_id
# tt0249516              12 -44926294  Winter
# tt0249516              12 -44926294  Winter
# tt0249516              12 -44926294  Winter
# tt0359950              12  96861183  Winter
# tt0359950              12  96861183  Winter

# %%
#join df with imdb_title_principals
principals_df = principals_df.set_index('movie_id')

joined_df = principals_df.join(rating_and_budgets, how='inner')

# %%
#drop ordering, job, and characters columns as we don't need this data for our analysis
joined_df = joined_df.drop(['ordering','job','characters','domestic_gross'], axis = 1)
# Out:
#            person_id  category      title original_title  runtime_minutes  \
# movie_id
# tt0249516  nm0257258  producer  foodfight     Foodfight!             91.0
# tt0249516  nm0257258  producer  foodfight     Foodfight!             91.0
# tt0249516  nm0257258  producer  foodfight     Foodfight!             91.0
# tt0249516  nm0240381   actress  foodfight     Foodfight!             91.0
# tt0249516  nm0240381   actress  foodfight     Foodfight!             91.0
#
#               genres release_date       movie  production_budget  \
# movie_id
# tt0249516     Action   2012-12-31  Foodfight!           45000000
# tt0249516  Animation   2012-12-31  Foodfight!           45000000
# tt0249516     Comedy   2012-12-31  Foodfight!           45000000
# tt0249516     Action   2012-12-31  Foodfight!           45000000
# tt0249516  Animation   2012-12-31  Foodfight!           45000000
#
#            worldwide_gross    days    months  year       ROI  months_numeric  \
# movie_id
# tt0249516            73706  Monday  December  2012 -0.998362              12
# tt0249516            73706  Monday  December  2012 -0.998362              12
# tt0249516            73706  Monday  December  2012 -0.998362              12
# tt0249516            73706  Monday  December  2012 -0.998362              12
# tt0249516            73706  Monday  December  2012 -0.998362              12
#
#              profit  season
# movie_id
# tt0249516 -44926294  Winter
# tt0249516 -44926294  Winter
# tt0249516 -44926294  Winter
# tt0249516 -44926294  Winter
# tt0249516 -44926294  Winter

# %%
joined_df
# Out:
#             person_id  category       title original_title  runtime_minutes  \
# movie_id
# tt0249516   nm0257258  producer   foodfight     Foodfight!             91.0
# tt0249516   nm0257258  producer   foodfight     Foodfight!             91.0
# tt0249516   nm0257258  producer   foodfight     Foodfight!             91.0
# tt0249516   nm0240381   actress   foodfight     Foodfight!             91.0
# tt0249516   nm0240381   actress   foodfight     Foodfight!             91.0
# ...               ...       ...         ...            ...              ...
# tt9889072   nm8492670  director  thepromise    The Promise              NaN
# tt9889072   nm8492674    writer  thepromise    The Promise              NaN
# tt9889072  nm10526600  producer  thepromise    The Promise              NaN
# tt9889072  nm10526597  producer  thepromise    The Promise              NaN
# tt9889072  nm10526599  producer  thepromise    The Promise              NaN
#
#               genres release_date        movie  production_budget  \
# movie_id
# tt0249516     Action   2012-12-31   Foodfight!           45000000
# tt0249516  Animation   2012-12-31   Foodfight!           45000000
# tt0249516     Comedy   2012-12-31   Foodfight!           45000000
# tt0249516     Action   2012-12-31   Foodfight!           45000000
# tt0249516  Animation   2012-12-31   Foodfight!           45000000
# ...              ...          ...          ...                ...
# tt9889072      Drama   2017-04-21  The Promise           90000000
# tt9889072      Drama   2017-04-21  The Promise           90000000
# tt9889072      Drama   2017-04-21  The Promise           90000000
# tt9889072      Drama   2017-04-21  The Promise           90000000
# tt9889072      Drama   2017-04-21  The Promise           90000000
#
#            worldwide_gross    days    months  year       ROI  months_numeric  \
# movie_id
# tt0249516            73706  Monday  December  2012 -0.998362              12
# tt0249516            73706  Monday  December  2012 -0.998362              12
# tt0249516            73706  Monday  December  2012 -0.998362              12
# tt0249516            73706  Monday  December  2012 -0.998362              12
# tt0249516            73706  Monday  December  2012 -0.998362              12
# ...                    ...     ...       ...   ...       ...             ...
# tt9889072         10551417  Friday     April  2017 -0.882762               4
# tt9889072         10551417  Friday     April  2017 -0.882762               4
# tt9889072         10551417  Friday     April  2017 -0.882762               4
# tt9889072         10551417  Friday     April  2017 -0.882762               4
# tt9889072         10551417  Friday     April  2017 -0.882762               4
#
#              profit  season
# movie_id
# tt0249516 -44926294  Winter
# tt0249516 -44926294  Winter
# tt0249516 -44926294  Winter
# tt0249516 -44926294  Winter
# tt0249516 -44926294  Winter
# ...             ...     ...
# tt9889072 -79448583  Spring
# tt9889072 -79448583  Spring
# tt9889072 -79448583  Spring
# tt9889072 -79448583  Spring
# tt9889072 -79448583  Spring
#
# [38342 rows x 17 columns]

# %%
joined_df = pd.merge(joined_df.reset_index(),persons_df,how = 'inner', on = 'person_id')

joined_df
# Out:
#         movie_id   person_id  category       title original_title  \
# 0      tt0249516   nm0257258  producer   foodfight     Foodfight!
# 1      tt0249516   nm0257258  producer   foodfight     Foodfight!
# 2      tt0249516   nm0257258  producer   foodfight     Foodfight!
# 3      tt0249516   nm0240381   actress   foodfight     Foodfight!
# 4      tt0249516   nm0240381   actress   foodfight     Foodfight!
# ...          ...         ...       ...         ...            ...
# 38334  tt9889072  nm10526588     actor  thepromise    The Promise
# 38335  tt9889072  nm10526591     actor  thepromise    The Promise
# 38336  tt9889072  nm10526600  producer  thepromise    The Promise
# 38337  tt9889072  nm10526597  producer  thepromise    The Promise
# 38338  tt9889072  nm10526599  producer  thepromise    The Promise
#
#        runtime_minutes     genres release_date        movie  \
# 0                 91.0     Action   2012-12-31   Foodfight!
# 1                 91.0  Animation   2012-12-31   Foodfight!
# 2                 91.0     Comedy   2012-12-31   Foodfight!
# 3                 91.0     Action   2012-12-31   Foodfight!
# 4                 91.0  Animation   2012-12-31   Foodfight!
# ...                ...        ...          ...          ...
# 38334              NaN      Drama   2017-04-21  The Promise
# 38335              NaN      Drama   2017-04-21  The Promise
# 38336              NaN      Drama   2017-04-21  The Promise
# 38337              NaN      Drama   2017-04-21  The Promise
# 38338              NaN      Drama   2017-04-21  The Promise
#
#        production_budget  ...    months  year       ROI  months_numeric  \
# 0               45000000  ...  December  2012 -0.998362              12
# 1               45000000  ...  December  2012 -0.998362              12
# 2               45000000  ...  December  2012 -0.998362              12
# 3               45000000  ...  December  2012 -0.998362              12
# 4               45000000  ...  December  2012 -0.998362              12
# ...                  ...  ...       ...   ...       ...             ...
# 38334           90000000  ...     April  2017 -0.882762               4
# 38335           90000000  ...     April  2017 -0.882762               4
# 38336           90000000  ...     April  2017 -0.882762               4
# 38337           90000000  ...     April  2017 -0.882762               4
# 38338           90000000  ...     April  2017 -0.882762               4
#
#          profit  season             primary_name birth_year death_year  \
# 0     -44926294  Winter          Robert Engelman        NaN        NaN
# 1     -44926294  Winter          Robert Engelman        NaN        NaN
# 2     -44926294  Winter          Robert Engelman        NaN        NaN
# 3     -44926294  Winter              Hilary Duff     1987.0        NaN
# 4     -44926294  Winter              Hilary Duff     1987.0        NaN
# ...         ...     ...                      ...        ...        ...
# 38334 -79448583  Spring  Nathanïel Berthil-Duval        NaN        NaN
# 38335 -79448583  Spring      Dieubert Charlestin        NaN        NaN
# 38336 -79448583  Spring          Dorival Farlone        NaN        NaN
# 38337 -79448583  Spring      James-Paul Gannaway        NaN        NaN
# 38338 -79448583  Spring    Dorival Jean-François        NaN        NaN
#
#                                    primary_profession
# 0      producer,assistant_director,production_manager
# 1      producer,assistant_director,production_manager
# 2      producer,assistant_director,production_manager
# 3                 actress,soundtrack,music_department
# 4                 actress,soundtrack,music_department
# ...                                               ...
# 38334                                            None
# 38335                                            None
# 38336                                            None
# 38337                                            None
# 38338                                            None
#
# [38339 rows x 22 columns]

# %%
#filter data for top 3 genres
df_people = joined_df[joined_df['genres'].isin(['Animation','Sci-Fi','Fantasy'])]

df_people
# Out:
#         movie_id  person_id  category        title original_title  \
# 1      tt0249516  nm0257258  producer    foodfight     Foodfight!
# 4      tt0249516  nm0240381   actress    foodfight     Foodfight!
# 7      tt0249516  nm0240380   actress    foodfight     Foodfight!
# 10     tt0249516  nm0000221     actor    foodfight     Foodfight!
# 13     tt0249516  nm0519456   actress    foodfight     Foodfight!
# ...          ...        ...       ...          ...            ...
# 38155  tt7634968  nm0326092    writer  whatmenwant  What Men Want
# 38158  tt7634968  nm3968623   actress  whatmenwant  What Men Want
# 38161  tt7634968  nm0404752    writer  whatmenwant  What Men Want
# 38164  tt7634968  nm0339733    writer  whatmenwant  What Men Want
# 38167  tt7634968  nm1944708    writer  whatmenwant  What Men Want
#
#        runtime_minutes     genres release_date          movie  \
# 1                 91.0  Animation   2012-12-31     Foodfight!
# 4                 91.0  Animation   2012-12-31     Foodfight!
# 7                 91.0  Animation   2012-12-31     Foodfight!
# 10                91.0  Animation   2012-12-31     Foodfight!
# 13                91.0  Animation   2012-12-31     Foodfight!
# ...                ...        ...          ...            ...
# 38155            117.0    Fantasy   2019-02-08  What Men Want
# 38158            117.0    Fantasy   2019-02-08  What Men Want
# 38161            117.0    Fantasy   2019-02-08  What Men Want
# 38164            117.0    Fantasy   2019-02-08  What Men Want
# 38167            117.0    Fantasy   2019-02-08  What Men Want
#
#        production_budget  ...    months  year       ROI  months_numeric  \
# 1               45000000  ...  December  2012 -0.998362              12
# 4               45000000  ...  December  2012 -0.998362              12
# 7               45000000  ...  December  2012 -0.998362              12
# 10              45000000  ...  December  2012 -0.998362              12
# 13              45000000  ...  December  2012 -0.998362              12
# ...                  ...  ...       ...   ...       ...             ...
# 38155           20000000  ...  February  2019  2.495595               2
# 38158           20000000  ...  February  2019  2.495595               2
# 38161           20000000  ...  February  2019  2.495595               2
# 38164           20000000  ...  February  2019  2.495595               2
# 38167           20000000  ...  February  2019  2.495595               2
#
#          profit  season     primary_name birth_year death_year  \
# 1     -44926294  Winter  Robert Engelman        NaN        NaN
# 4     -44926294  Winter      Hilary Duff     1987.0        NaN
# 7     -44926294  Winter      Haylie Duff     1985.0        NaN
# 10    -44926294  Winter    Charlie Sheen     1965.0        NaN
# 13    -44926294  Winter     Eva Longoria     1975.0        NaN
# ...         ...     ...              ...        ...        ...
# 38155  49911903  Winter   Josh Goldsmith     1970.0        NaN
# 38158  49911903  Winter   Kristen Ledlow        NaN        NaN
# 38161  49911903  Winter      Peter Huyck        NaN        NaN
# 38164  49911903  Winter     Alex Gregory        NaN        NaN
# 38167  49911903  Winter       Jas Waters        NaN        NaN
#
#                                    primary_profession
# 1      producer,assistant_director,production_manager
# 4                 actress,soundtrack,music_department
# 7                         actress,producer,soundtrack
# 10                          actor,producer,soundtrack
# 13                          actress,producer,director
# ...                                               ...
# 38155                producer,writer,music_department
# 38158                      actress,assistant_director
# 38161                   writer,producer,miscellaneous
# 38164                   writer,producer,miscellaneous
# 38167                       writer,assistant_director
#
# [3584 rows x 22 columns]

# %%
#update the DataFrame to include coloumns that we need for analysis
df_people_new = df_people[['person_id','category','genres','production_budget','worldwide_gross','primary_name','ROI']]

df_people_new
# Out:
#        person_id  category     genres  production_budget  worldwide_gross  \
# 1      nm0257258  producer  Animation           45000000            73706
# 4      nm0240381   actress  Animation           45000000            73706
# 7      nm0240380   actress  Animation           45000000            73706
# 10     nm0000221     actor  Animation           45000000            73706
# 13     nm0519456   actress  Animation           45000000            73706
# ...          ...       ...        ...                ...              ...
# 38155  nm0326092    writer    Fantasy           20000000         69911903
# 38158  nm3968623   actress    Fantasy           20000000         69911903
# 38161  nm0404752    writer    Fantasy           20000000         69911903
# 38164  nm0339733    writer    Fantasy           20000000         69911903
# 38167  nm1944708    writer    Fantasy           20000000         69911903
#
#           primary_name       ROI
# 1      Robert Engelman -0.998362
# 4          Hilary Duff -0.998362
# 7          Haylie Duff -0.998362
# 10       Charlie Sheen -0.998362
# 13        Eva Longoria -0.998362
# ...                ...       ...
# 38155   Josh Goldsmith  2.495595
# 38158   Kristen Ledlow  2.495595
# 38161      Peter Huyck  2.495595
# 38164     Alex Gregory  2.495595
# 38167       Jas Waters  2.495595
#
# [3584 rows x 7 columns]

# %%
#group the columns to get the total production budget & worldwide gross revenue by person, genre, and category
df_people_grouped = df_people_new.groupby(by = ['person_id','primary_name','genres','category']).sum()

df_people_grouped
# Out:
#                                                          production_budget  \
# person_id primary_name               genres    category
# nm0000092 John Cleese                Animation actor              30000000
#                                                writer            135000000
# nm0000093 Brad Pitt                  Animation actor             130000000
#                                      Fantasy   actor              35000000
# nm0000095 Woody Allen                Fantasy   director           30000000
# ...                                                                    ...
# nm9204083 Ole Kirk Christiansen      Animation writer             60000000
# nm9204084 Godtfred Kirk Christiansen Animation writer             60000000
# nm9339179 Steven Young               Sci-Fi    actor                 70000
# nm9339181 Fil Hill                   Sci-Fi    composer              70000
# nm9545038 Julien Rey                 Sci-Fi    editor             40000000
#
#                                                          worldwide_gross  \
# person_id primary_name               genres    category
# nm0000092 John Cleese                Animation actor            50145607
#                                                writer          573068425
# nm0000093 Brad Pitt                  Animation actor           321887208
#                                      Fantasy   actor            61721826
# nm0000095 Woody Allen                Fantasy   director        162502774
# ...                                                                  ...
# nm9204083 Ole Kirk Christiansen      Animation writer          457729388
# nm9204084 Godtfred Kirk Christiansen Animation writer          457729388
# nm9339179 Steven Young               Sci-Fi    actor                8555
# nm9339181 Fil Hill                   Sci-Fi    composer             8555
# nm9545038 Julien Rey                 Sci-Fi    editor          457507776
#
#                                                                ROI
# person_id primary_name               genres    category
# nm0000092 John Cleese                Animation actor      0.671520
#                                                writer     3.244951
# nm0000093 Brad Pitt                  Animation actor      1.476055
#                                      Fantasy   actor      0.763481
# nm0000095 Woody Allen                Fantasy   director   4.416759
# ...                                                            ...
# nm9204083 Ole Kirk Christiansen      Animation writer     6.628823
# nm9204084 Godtfred Kirk Christiansen Animation writer     6.628823
# nm9339179 Steven Young               Sci-Fi    actor     -0.877786
# nm9339181 Fil Hill                   Sci-Fi    composer  -0.877786
# nm9545038 Julien Rey                 Sci-Fi    editor    10.437694
#
# [2865 rows x 3 columns]

# %%
df_people_grouped.reset_index(inplace = True)

df_people_grouped
# Out:
#       person_id                primary_name     genres  category  \
# 0     nm0000092                 John Cleese  Animation     actor
# 1     nm0000092                 John Cleese  Animation    writer
# 2     nm0000093                   Brad Pitt  Animation     actor
# 3     nm0000093                   Brad Pitt    Fantasy     actor
# 4     nm0000095                 Woody Allen    Fantasy  director
# ...         ...                         ...        ...       ...
# 2860  nm9204083       Ole Kirk Christiansen  Animation    writer
# 2861  nm9204084  Godtfred Kirk Christiansen  Animation    writer
# 2862  nm9339179                Steven Young     Sci-Fi     actor
# 2863  nm9339181                    Fil Hill     Sci-Fi  composer
# 2864  nm9545038                  Julien Rey     Sci-Fi    editor
#
#       production_budget  worldwide_gross        ROI
# 0              30000000         50145607   0.671520
# 1             135000000        573068425   3.244951
# 2             130000000        321887208   1.476055
# 3              35000000         61721826   0.763481
# 4              30000000        162502774   4.416759
# ...                 ...              ...        ...
# 2860           60000000        457729388   6.628823
# 2861           60000000        457729388   6.628823
# 2862              70000             8555  -0.877786
# 2863              70000             8555  -0.877786
# 2864           40000000        457507776  10.437694
#
# [2865 rows x 7 columns]

# %%
#function to show top 5 individuals by genre
def people_genre_plot(df, genre, category, n = 5):
    
    #filter for genre
    df = df[df['genres'] == genre]
    
    #filter for category
    df = df[df['category'] == category]
    
    #sort by gross
    df = df.sort_values(by = 'ROI', ascending = False)
    
    #create a list of individuals so we can limit to a number of individuals
    nconsts = df['person_id'].unique()
    
    #limit to number of people
    df = df[df['person_id'].isin(nconsts[:n])]
    
    
   
    
    # =plot the figure
    sns.set_theme()
    # Set your custom color palette
    #colors = ["#86BC25","#C4D600","#E3E48D"]
    #customPalette = sns.set_palette(colors)
    customPalette = sns.color_palette("Blues", as_cmap=False)
    plt.figure (figsize = (12,6))
    ax = sns.barplot(data = df,
               y = 'primary_name',
               x = 'ROI', palette=customPalette)
    
    #add a title for the plot            
    plt.title('Top 5 ' + category.title() + 's in ' + genre + ' Movies', fontsize = 15, pad = 20)
    
    
    # add and adjust labels
    ax.set_xlabel('ROI', fontsize = 13)
    #ax.yaxis.label.set_visible(False)
    ax.tick_params(labelsize = 12)
   # ax.get_xaxis().set_major_formatter(
   # matplotlib.ticker.FuncFormatter(lambda x, p: format(int(x), ',')))

# %%
people_genre_plot(df_people_grouped, 'Animation', 'actor')

# %%
people_genre_plot(df_people_grouped, 'Sci-Fi', 'actor')

# %%
people_genre_plot(df_people_grouped, 'Fantasy', 'actor')

# %%
people_genre_plot(df_people_grouped, 'Animation', 'director')

# %%
people_genre_plot(df_people_grouped, 'Fantasy', 'director')

# %%
people_genre_plot(df_people_grouped, 'Sci-Fi', 'director')

# %%
sorted_df = rating_and_budgets.sort_values(by=['months_numeric'])

# %%
animated_df=sorted_df[sorted_df['genres']=='Animation']
animated_df = animated_df.drop_duplicates('title')
animated_df = animated_df.groupby(['months_numeric']).worldwide_gross.mean()

# Create a figure and axis
fig, ax = plt.subplots(figsize=(12,6))

# Get x and y data
x1 = animated_df.index
y1 = animated_df.values

ax.bar(x1, y1, color='#0D8390')

months =['Jan','Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul','Aug', 'Sep', 'Oct', 'Nov', 'Dec']
months_num = range(1,13)
ax.set_xticks(months_num)
ax.set_xticklabels(months)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
ax.set_title('Monthly Average Gross of Animation movies', fontsize=14)
ax.set_xlabel('Month', fontsize=15)
ax.set_ylabel('Average Gross', fontsize=15)
ax.get_yaxis().set_major_formatter(
    matplotlib.ticker.FuncFormatter(lambda x, p: format(int(x), ',')))

# %%
sci_df=sorted_df[sorted_df['genres']=='Sci-Fi']
sci_df = sci_df.drop_duplicates('title')
sci_df = sci_df.groupby(['months_numeric']).worldwide_gross.mean()

# Create a figure and axis
fig, ax = plt.subplots(figsize=(12,6))

# Get x and y data
x1 = sci_df.index
y1 = sci_df.values

ax.bar(x1, y1, color='#046A38')

months =['Jan','Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul','Aug', 'Sep', 'Oct', 'Nov', 'Dec']
months_num = range(1,13)
ax.set_xticks(months_num)
ax.set_xticklabels(months)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
ax.set_title('Monthly Average Gross of Sci-Fi movies', fontsize=14)
ax.set_xlabel('Month', fontsize=15)
ax.set_ylabel('Average Gross', fontsize=15)
ax.get_yaxis().set_major_formatter(
    matplotlib.ticker.FuncFormatter(lambda x, p: format(int(x), ',')))

# %%
import matplotlib
sns.set_theme()

fantasy_df=sorted_df[sorted_df['genres']=='Fantasy']
fantasy_df = fantasy_df.drop_duplicates('title')
fantasy_df = fantasy_df.groupby(['months_numeric']).worldwide_gross.mean()

# Create a figure and axis
fig, ax = plt.subplots(figsize=(12,6))

# Get x and y data
x1 = fantasy_df.index
y1 = fantasy_df.values

ax.bar(x1, y1, color='#86BC25')

months =['Jan','Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul','Aug', 'Sep', 'Oct', 'Nov', 'Dec']
months_num = range(1,13)
ax.set_xticks(months_num)
ax.set_xticklabels(months)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
ax.set_title('Monthly Average Gross of Fantasy movies', fontsize=14)
ax.set_xlabel('Month', fontsize=14)
ax.set_ylabel('Average Gross', fontsize=14)
ax.get_yaxis().set_major_formatter(
    matplotlib.ticker.FuncFormatter(lambda x, p: format(int(x), ',')))
